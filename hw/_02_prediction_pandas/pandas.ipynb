# %%
import pandas as pd
df = pd.read_csv('../../data/car_sales_cleaned1.csv')
df = df.drop_duplicates()
df = df.dropna()

# %%
# df_hyundai = df[df['Company'] == 'Hyundai']
df_hyundai = df[df['Company'] == 'Hyundai'].reset_index()
df_hyundai
# Out:
#      index  Gender  Annual Income  Company    Model Transmission       Color  \
# 0       16  Female         535000  Hyundai   Accent       Manual       Black
# 1      124  Female        1690000  Hyundai   Sonata       Manual       Black
# 2      168    Male         955000  Hyundai  Elantra       Manual  Pale White
# 3      250    Male         457000  Hyundai   Sonata       Manual  Pale White
# 4      289    Male          13500  Hyundai   Sonata       Manual       Black
# ..     ...     ...            ...      ...      ...          ...         ...
# 219  23248  Female        1675000  Hyundai   Sonata       Manual       Black
# 220  23432  Female          13500  Hyundai  Elantra       Manual         Red
# 221  23650  Female         460000  Hyundai   Sonata       Manual       Black
# 222  23738    Male         705000  Hyundai   Sonata       Manual         Red
# 223  23745    Male         681500  Hyundai   Accent       Manual       Black
#
#      Price ($)
# 0        18000
# 1        15000
# 2        26000
# 3        21000
# 4        20000
# ..         ...
# 219      20500
# 220      22000
# 221      15000
# 222      21000
# 223      18500
#
# [224 rows x 8 columns]

# %%
df_toyota = df[(df['Company'] == 'Toyota') & (df['Price ($)'] > 40000)]
df_toyota
# Out:
#        Gender  Annual Income Company    Model Transmission       Color  \
# 239      Male        1350000  Toyota   Tacoma         Auto  Pale White
# 258      Male        1151000  Toyota  Corolla         Auto  Pale White
# 269    Female         825000  Toyota   Tacoma       Manual  Pale White
# 308    Female          13500  Toyota  Corolla         Auto  Pale White
# 358      Male        1326000  Toyota     RAV4       Manual       Black
# ...       ...            ...     ...      ...          ...         ...
# 23379    Male        1300000  Toyota   Celica         Auto  Pale White
# 23385  Female         615000  Toyota   Tacoma         Auto  Pale White
# 23443    Male        2400000  Toyota     RAV4       Manual       Black
# 23476    Male         520000  Toyota   Celica         Auto  Pale White
# 23735    Male        1635000  Toyota   Tacoma         Auto  Pale White
#
#        Price ($)
# 239        53000
# 258        41100
# 269        82000
# 308        41000
# 358        85600
# ...          ...
# 23379      45001
# 23385      53000
# 23443      85000
# 23476      45000
# 23735      53501
#
# [175 rows x 7 columns]

# %%
df['Model'].value_counts().head(3)
# Out:
# Model
# Prizm         362
# Diamante      347
# Silhouette    337
# Name: count, dtype: int64

# %%
most_popular_cars = df[['Company','Model']].value_counts().head(3) # head daet 5 pervih strok
most_popular_cars
# Out:
# Company     Model
# Chevrolet   Prizm         362
# Mitsubishi  Diamante      347
# Oldsmobile  Silhouette    337
# Name: count, dtype: int64
