# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt

model = YOLO('runs/detect/circle_exp/weights/best.pt')
results = model('images2.jpg', conf=0.6)
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
