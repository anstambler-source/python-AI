# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('runs/detect/circle_exp/weights/best.pt')
results = model('datasets/images/val/img1.jpg')
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 D:\Python Project\TelRan\PythonProject\python-ai-62test\06_yolo_training\datasets\images\val\img1.jpg: 256x256 1 circle, 54.3ms
# Speed: 3.6ms preprocess, 54.3ms inference, 3.6ms postprocess per image at shape (1, 3, 256, 256)
